# %% [markdown]
# ### Camera socket live stream:
#
#
#
# ```bash
#
# libcamera-vid -t 0 --inline --listen -o tcp://0.0.0.0:5000
# ```

# %%
import cv2

# Replace with your Raspberry Pi's IP
raspberry_pi_ip = "100.73.143.76"
port = "5000"  # Make sure this matches your `libcamera-vid` port

stream_url = f"tcp://{raspberry_pi_ip}:{port}"

cap = cv2.VideoCapture(stream_url)

if not cap.isOpened():
    print("Error: Cannot open stream. Check IP and port.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame.")
        break
    
    # Flip the frame vertically
    frame = cv2.flip(frame, 0)

    cv2.imshow("Raspberry Pi Camera Stream", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Failed to grab frame.

# %% [markdown]
# ## YOLO v8n imp

# %%
# Out:
# Model summary (fused): 168 layers, 3,009,158 parameters, 0 gradients, 8.1 GFLOPs
#
# 0: 480x640 1 Can, 1 Pop tab, 97.3ms
# Speed: 5.4ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 87.7ms
# Speed: 2.1ms preprocess, 87.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 86.6ms
# Speed: 2.6ms preprocess, 86.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 115.9ms
# Speed: 2.0ms preprocess, 115.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.5ms
# Speed: 2.7ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.1ms
# Speed: 2.1ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 84.1ms
# Speed: 2.3ms preprocess, 84.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 82.6ms
# Speed: 2.0ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 101.8ms
# Speed: 2.1ms preprocess, 101.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 83.7ms
# Speed: 1.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.4ms
# Speed: 2.1ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.0ms
# Speed: 2.2ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.8ms
# Speed: 1.6ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.2ms
# Speed: 1.6ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.9ms
# Speed: 1.9ms preprocess, 79.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.8ms
# Speed: 1.6ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 90.9ms
# Speed: 2.0ms preprocess, 90.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 82.8ms
# Speed: 3.1ms preprocess, 82.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.6ms
# Speed: 1.7ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.5ms
# Speed: 1.7ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.2ms
# Speed: 1.6ms preprocess, 79.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.3ms
# Speed: 2.6ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.7ms
# Speed: 2.0ms preprocess, 77.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.5ms
# Speed: 1.6ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.8ms
# Speed: 2.0ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 70.4ms
# Speed: 1.0ms preprocess, 70.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.9ms
# Speed: 3.0ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 72.9ms
# Speed: 2.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.6ms
# Speed: 2.0ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 89.7ms
# Speed: 1.7ms preprocess, 89.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 76.9ms
# Speed: 2.0ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 95.3ms
# Speed: 2.0ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 104.2ms
# Speed: 1.0ms preprocess, 104.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.4ms
# Speed: 2.0ms preprocess, 77.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.7ms
# Speed: 1.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.0ms
# Speed: 1.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 113.0ms
# Speed: 2.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 105.0ms
# Speed: 14.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 66.7ms
# Speed: 2.0ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.7ms
# Speed: 1.5ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 70.4ms
# Speed: 2.0ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 91.6ms
# Speed: 3.0ms preprocess, 91.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.4ms
# Speed: 2.0ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.3ms
# Speed: 2.5ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 89.4ms
# Speed: 2.0ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.1ms
# Speed: 1.6ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 72.5ms
# Speed: 1.5ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.5ms
# Speed: 2.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 76.6ms
# Speed: 1.6ms preprocess, 76.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 78.3ms
# Speed: 2.2ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 76.9ms
# Speed: 1.7ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 83.7ms
# Speed: 3.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.4ms
# Speed: 1.5ms preprocess, 75.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 70.2ms
# Speed: 1.6ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.7ms
# Speed: 3.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 76.4ms
# Speed: 2.0ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.7ms
# Speed: 2.1ms preprocess, 79.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.6ms
# Speed: 2.1ms preprocess, 77.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.2ms
# Speed: 2.1ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.4ms
# Speed: 2.0ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 81.3ms
# Speed: 2.0ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.3ms
# Speed: 2.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.4ms
# Speed: 2.1ms preprocess, 79.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 82.0ms
# Speed: 1.5ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.7ms
# Speed: 2.0ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 106.0ms
# Speed: 1.5ms preprocess, 106.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.2ms
# Speed: 1.8ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 109.8ms
# Speed: 3.0ms preprocess, 109.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 118.1ms
# Speed: 1.5ms preprocess, 118.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 95.3ms
# Speed: 2.5ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 103.4ms
# Speed: 4.2ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 99.8ms
# Speed: 3.0ms preprocess, 99.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 110.4ms
# Speed: 3.0ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 92.7ms
# Speed: 2.0ms preprocess, 92.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 127.9ms
# Speed: 1.7ms preprocess, 127.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 134.1ms
# Speed: 2.0ms preprocess, 134.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 138.2ms
# Speed: 3.0ms preprocess, 138.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 121.2ms
# Speed: 3.0ms preprocess, 121.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 130.2ms
# Speed: 5.7ms preprocess, 130.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 178.1ms
# Speed: 3.0ms preprocess, 178.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 152.0ms
# Speed: 4.0ms preprocess, 152.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 151.4ms
# Speed: 4.0ms preprocess, 151.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 104.3ms
# Speed: 2.0ms preprocess, 104.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.3ms
# Speed: 2.0ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 83.0ms
# Speed: 2.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.9ms
# Speed: 2.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 83.0ms
# Speed: 1.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 82.3ms
# Speed: 2.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 109.4ms
# Speed: 4.0ms preprocess, 109.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.6ms
# Speed: 1.0ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 116.6ms
# Speed: 2.0ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 85.2ms
# Speed: 2.0ms preprocess, 85.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 85.4ms
# Speed: 4.7ms preprocess, 85.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 85.0ms
# Speed: 1.6ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 92.4ms
# Speed: 1.6ms preprocess, 92.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 81.4ms
# Speed: 2.7ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 151.4ms
# Speed: 1.5ms preprocess, 151.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 89.8ms
# Speed: 13.0ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.2ms
# Speed: 3.5ms preprocess, 79.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 83.3ms
# Speed: 2.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 83.1ms
# Speed: 2.0ms preprocess, 83.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.9ms
# Speed: 2.1ms preprocess, 75.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.6ms
# Speed: 2.5ms preprocess, 79.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.9ms
# Speed: 1.5ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.0ms
# Speed: 2.1ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 78.3ms
# Speed: 1.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 78.6ms
# Speed: 4.0ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.2ms
# Speed: 2.0ms preprocess, 80.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 76.4ms
# Speed: 2.0ms preprocess, 76.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 82.2ms
# Speed: 1.0ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 1.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 91.0ms
# Speed: 1.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.7ms
# Speed: 2.0ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 1.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.2ms
# Speed: 2.1ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 92.4ms
# Speed: 2.0ms preprocess, 92.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 85.4ms
# Speed: 1.7ms preprocess, 85.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 78.9ms
# Speed: 1.6ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 76.3ms
# Speed: 2.1ms preprocess, 76.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.8ms
# Speed: 2.1ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 82.7ms
# Speed: 1.0ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.0ms
# Speed: 3.1ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 93.4ms
# Speed: 2.0ms preprocess, 93.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 90.8ms
# Speed: 3.1ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 87.3ms
# Speed: 2.1ms preprocess, 87.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 90.3ms
# Speed: 2.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 84.3ms
# Speed: 2.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 85.9ms
# Speed: 1.7ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 83.3ms
# Speed: 1.6ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 82.9ms
# Speed: 2.1ms preprocess, 82.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 81.0ms
# Speed: 2.5ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 84.8ms
# Speed: 1.8ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 82.9ms
# Speed: 2.0ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 81.5ms
# Speed: 1.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 90.2ms
# Speed: 2.0ms preprocess, 90.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 80.1ms
# Speed: 2.4ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 77.1ms
# Speed: 1.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 72.0ms
# Speed: 1.7ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.0ms
# Speed: 4.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.5ms
# Speed: 1.5ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 67.6ms
# Speed: 2.0ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.8ms
# Speed: 1.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.4ms
# Speed: 2.0ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.0ms
# Speed: 1.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.3ms
# Speed: 1.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.7ms
# Speed: 1.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.0ms
# Speed: 1.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 1.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.0ms
# Speed: 1.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.9ms
# Speed: 2.0ms preprocess, 68.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 67.2ms
# Speed: 2.0ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 86.0ms
# Speed: 1.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 84.0ms
# Speed: 4.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 1 Styrofoam piece, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Pop tab, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 67.8ms
# Speed: 3.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Can, 1 Pop tab, 87.0ms
# Speed: 1.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Failed to grab frame.

# %%
import socket

# Replace with your Raspberry Pi's IP address
RASPBERRY_PI_IP = "100.73.143.76"  # Update this with your actual Raspberry Pi's IP
PORT = 6000

# Define which servos are reversed (same as in `servo.py`)
REVERSED_SERVOS = {"0": False, "1": True}  # Only Servos 0 and 1 exist

# Create the socket connection
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client_socket.connect((RASPBERRY_PI_IP, PORT))

print("🚀 Connected to Raspberry Pi!")
print("Type commands like:")
print("   'forward 2.5'   → Move forward for 2.5 sec")
print("   'left 1.5'      → Turn left for 1.5 sec")
print("   'servo 0 120'   → Move Servo 0 to 120°")
print("   'servo 1 90'    → Move Servo 1 to 90°")
print("   'servo 1 90 rev' → Move Servo 1 to the opposite direction")
print("   'servo stop'    → Stop all servos")
print("   'stop'          → Stop the robot")
print("   'exit'          → Shut down the server")

try:
    while True:
        command = input("Enter command: ").strip().lower()
        parts = command.split()

        # Stop all servos command
        if command == "servo stop":
            client_socket.sendall(command.encode())

        # Check if the user is trying to move a servo in reverse
        elif len(parts) == 4 and parts[0] == "servo" and parts[3] == "rev":
            servo_id = parts[1]
            angle = int(parts[2])

            if servo_id in REVERSED_SERVOS and REVERSED_SERVOS[servo_id]:
                angle = 180 - angle  # Reverse the angle
                print(f"↩️ Adjusting Servo {servo_id} to {angle}° (Opposite Direction)")

            # Send adjusted command
            command = f"servo {servo_id} {angle}"
            client_socket.sendall(command.encode())

        else:
            client_socket.sendall(command.encode())

        if command == "exit":
            print("Exiting...")
            break

except KeyboardInterrupt:
    print("\nClosing connection...")

finally:
    client_socket.close()
# Out:
# 🚀 Connected to Raspberry Pi!
# Type commands like:
#    'forward 2.5'   → Move forward for 2.5 sec
#    'left 1.5'      → Turn left for 1.5 sec
#    'servo 0 120'   → Move Servo 0 to 120°
#    'servo 1 90'    → Move Servo 1 to 90°
#    'servo 1 90 rev' → Move Servo 1 to the opposite direction
#    'servo stop'    → Stop all servos
#    'stop'          → Stop the robot
#    'exit'          → Shut down the server
# Enter command:  forward 1
# Enter command:  backward 1
# Enter command:  backward 2
# Enter command:  forward 1
# Enter command:
# Enter command:  forward 1
# Enter command:  left 5
# Enter command:  exit
# Exiting...
